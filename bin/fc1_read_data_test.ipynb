# %%
# read spacety_SLC_SM_2537_20231126T031505_Sub1.h5 file and display it.
import h5py
import matplotlib.pyplot as plt

# read file
f = h5py.File('spacety_SLC_SM_2537_20231126T031505_Sub1/spacety_SLC_SM_2537_20231126T031505_Sub1.h5', 'r')

# %%
# display f as image
print("Keys: %s" % f.keys())
# Out:
# Keys: <KeysViewHDF5 ['RPC', 'acquisition_end_utc', 'acquisition_id', 'acquisition_mode', 'acquisition_prf', 'acquisition_start_utc', 'angX', 'angY', 'angZ', 'ant_elev_corr_flag', 'antenna_pattern_compensation', 'avg_scene_height', 'azimuth_ground_spacing', 'azimuth_looks', 'azimuth_time_interval', 'calibration_factor', 'carrier_frequency', 'chirp_bandwidth', 'chirp_duration', 'coord_center', 'coord_first_far', 'coord_first_near', 'coord_last_far', 'coord_last_near', 'data_orientation', 'dc_estimate_coeffs', 'dc_estimate_poly_order', 'dc_estimate_time_utc', 'doppler_rate_coeffs', 'doppler_rate_poly_order', 'first_pixel_time', 'fsl_compensation', 'geo_ref_system', 'heading', 'height_spline', 'incidence_center', 'incidence_far', 'incidence_near', 'lat_spline', 'local_incidence_angle', 'lon_spline', 'look_side', 'mean_earth_radius', 'mean_orbit_altitude', 'number_of_azimuth_samples', 'number_of_dc_estimations', 'number_of_range_samples', 'number_of_state_vectors', 'orbit_absolute_number'
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Use the variable 'f' from the previous cell
data = f["s_i"][:]**2 + f["s_q"][:]**2
print(data.shape)
print(type(data))

# save data as a png
import matplotlib
matplotlib.image.imsave('test.png', data)

# # set plt.imshow dpi to be 1000
# plt.rcParams['figure.dpi'] = 1000
# plt.imshow(data, clim=(0, 10000))
# Out:
# (20236, 22866)
# <class 'numpy.ndarray'>
